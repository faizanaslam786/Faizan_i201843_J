# %%
# pip install numpy
import numpy as np

# %% [markdown]
# # Task1-i Making random 1X2 vector

# %%
import numpy as np
import pandas as pd
import math

# %%
v1=np.random.randint(1,9,size=(1,2))
v1
# Out:
# array([[7, 3]])

# %% [markdown]
# # Task1-ii making orthogonal vector

# %%
v2=np.flip(v1)
v2=np.array([-v2[0][0],v2[0][1]])
v2
# Out:
# array([-3,  7])

# %%
v1
# Out:
# array([[7, 3]])

# %% [markdown]
# # Task1-iii making projections on each other

# %%
tmp=math.sqrt(np.dot(v1,v1.T))
proj2=(((np.dot(v1,v2))/tmp))*v1
print("Projection of v2 on v1 : ",proj2)

tmp2=math.sqrt(np.dot(v2,v2.T))
proj1=(((np.dot(v1,v2))/tmp2))*v2
print("Projection of v1 on v2 : ",proj1)
# Out:
# Projection of v2 on v1 :  [[0. 0.]]
# Projection of v1 on v2 :  [-0.  0.]

# %% [markdown]
# # Task1-iv Finding initial vectors from projection

# %%
print("We cannot find initial vectors from projections beacuse all enteries are zero now and their previous enteries has been lost")
# Out:
# We cannot find initial vectors from projections beacuse all enteries are zero now and their previous enteries has been lost

# %% [markdown]
# # Task1-v Findi eigenvalues and eigenvectors of iris data set

# %%
df=pd.read_csv(f'iris.csv')
df.drop('variety' ,inplace=True, axis=1)

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
tv=df[['sepal.length', 'sepal.width','petal.length','petal.width']].to_numpy()
tv
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
tv=np.asmatrix(tv)
tv=tv *tv.T
tv.shape
# Out:
# (150, 150)

# %%
tv.shape
# Out:
# (150, 150)

# %%
eigenvalues,eigenvectors = np.linalg.eig(tv)
print("Eigen vectors :",eigenvectors,'\n Eigen values',eigenvalues)
# Out:
# Eigen vectors : [[ 6.16168450e-02+0.j -1.29611444e-01+0.j -2.13859674e-03+0.j ...
#   -1.11101160e-01+0.j -1.00105252e-01+0.j -1.58980246e-15+0.j]
#  [ 5.80709402e-02+0.j -1.11019776e-01+0.j -7.06723871e-02+0.j ...
#    9.29931089e-03+0.j -1.44012339e-04+0.j  1.63822270e-16+0.j]
#  [ 5.67630474e-02+0.j -1.17966465e-01+0.j -4.34254909e-03+0.j ...
#    7.35620623e-03+0.j  1.26187577e-02+0.j  3.78091651e-17+0.j]
#  ...
#  [ 9.40593040e-02+0.j  4.98296974e-02+0.j  4.14400144e-02+0.j ...
#   -3.85583612e-02+0.j -7.51433097e-02+0.j -8.09621642e-16+0.j]
#  [ 9.48896096e-02+0.j  5.61012256e-02+0.j  2.12978214e-01+0.j ...
#    1.14486850e-01+0.j  7.11128093e-02+0.j  1.20114894e-15+0.j]
#  [ 8.84783560e-02+0.j  5.15697045e-02+0.j  9.57528475e-02+0.j ...
#    4.69514767e-03+0.j -7.81622642e-02+0.j -1.66468716e-16+0.j]]
#  Eigen values [ 9.20830507e+03+0.00000000e+00j  3.15454317e+02+0.00000000e+00j
#   1.19780429e+01+0.00000000e+00j  3.55257020e+00+0.00000000e+00j
# ...

# %% [markdown]
# # Task2-i Changing the Iris data to zero-centered data

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
mean= np.mean(df,axis=0) # takes mean across examples(along rows)
mean
# Out:
# sepal.length    5.843333
# sepal.width     3.057333
# petal.length    3.758000
# petal.width     1.199333
# dtype: float64

# %%
zero_centered=df-df.mean()
print(" Zero centered of Iris ")
zero_centered
# Out:
#  Zero centered of Iris
#      sepal.length  sepal.width  petal.length  petal.width
# 0       -0.743333     0.442667        -2.358    -0.999333
# 1       -0.943333    -0.057333        -2.358    -0.999333
# 2       -1.143333     0.142667        -2.458    -0.999333
# 3       -1.243333     0.042667        -2.258    -0.999333
# 4       -0.843333     0.542667        -2.358    -0.999333
# ..            ...          ...           ...          ...
# 145      0.856667    -0.057333         1.442     1.100667
# 146      0.456667    -0.557333         1.242     0.700667
# 147      0.656667    -0.057333         1.442     0.800667
# 148      0.356667     0.342667         1.642     1.100667
# 149      0.056667    -0.057333         1.342     0.600667
#
# [150 rows x 4 columns]

# %% [markdown]
# # # Task2-ii Changing the ECG data to zero-centered data

# %%
df2=pd.read_csv(f'ECG200_TRAIN.csv',delimiter='  ')
df2
# Out:
# <ipython-input-17-64b330830981>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df2=pd.read_csv(f'ECG200_TRAIN.csv',delimiter='  ')
#     -1.0000000e+00   5.0205548e-01   5.4216265e-01   7.2238348e-01  \
# 0              1.0        0.147647        0.804668        0.367771
# 1             -1.0        0.316646        0.243199        0.370471
# 2             -1.0        1.168874        2.075901        1.760141
# 3              1.0        0.648658        0.752026        2.636231
# 4              1.0        0.404733        1.280859        2.515148
# ..             ...             ...             ...             ...
# 94             1.0        0.581277        0.876188        1.042767
# 95            -1.0        2.689017        2.708703        2.008381
# ...

# %%
df2.drop('-1.0000000e+00',inplace=True,axis=1)
df2
# Out:
#      5.0205548e-01   5.4216265e-01   7.2238348e-01   1.4288852e+00  \
# 0         0.147647        0.804668        0.367771        0.243894
# 1         0.316646        0.243199        0.370471        1.063738
# 2         1.168874        2.075901        1.760141        1.606446
# 3         0.648658        0.752026        2.636231        3.455716
# 4         0.404733        1.280859        2.515148        1.299519
# ..             ...             ...             ...             ...
# 94        0.581277        0.876188        1.042767        1.796120
# 95        2.689017        2.708703        2.008381        2.235800
# 96        0.197677        0.455417        0.973110        1.935956
# 97        0.179500        1.038409        1.946421        2.705141
# 98        0.073124        0.776054        2.181336        3.440325
#
#      2.1365158e+00   2.2811490e+00   1.9362737e+00   1.4688900e+00  \
# 0         0.026614       -0.274402        0.096731       -0.747731
# ...

# %%
zero_centered2=df2-df2.mean()
print(" Zero centered of ECG ")
zero_centered2
# Out:
#  Zero centered of ECG
#      5.0205548e-01   5.4216265e-01   7.2238348e-01   1.4288852e+00  \
# 0        -0.562875       -0.626371       -1.684678       -1.889607
# 1        -0.393876       -1.187841       -1.681978       -1.069763
# 2         0.458352        0.644861       -0.292309       -0.527055
# 3        -0.061865       -0.679014        0.583781        1.322214
# 4        -0.305790       -0.150181        0.462698       -0.833982
# ..             ...             ...             ...             ...
# 94       -0.129245       -0.554852       -1.009683       -0.337381
# 95        1.978495        1.277664       -0.044068        0.102299
# 96       -0.512845       -0.975623       -1.079340       -0.197545
# 97       -0.531022       -0.392631       -0.106029        0.571640
# 98       -0.637398       -0.654986        0.128886        1.306824
#
#      2.1365158e+00   2.2811490e+00   1.9362737e+00   1.4688900e+00  \
# 0        -1.519094       -1.021311       -0.169213       -1.069893
# ...

# %% [markdown]
# # Completed task
